# %% [markdown]
# # ****TradeFlow Dashboard****
#
# * **Student Name: Nidhi Gupta**
# * **Enrollment Number: 055006**
#
#
# ---

# %% [markdown]
# **PROJECT INFORMATION**
# Analysis of Import and Export Transactions| Nidhi Gupta| 055006|

# %% [markdown]
# **Description of Data**
# Data Source & Siz -  Kaggle](https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000) & 1 MB
# No. of rows in the data are: 2001
# No. of columns in the data are: 16Number of Observations in the dataset are: 2001gNumber of Variables are: 16
# List of Variables are: ['Transaction_ID', 'Country', 'Product', 'Import_Export', 'Quantity', 'Value', 'Date', 'Category', 'Port', 'Customs_Code', 'Weight', 'Shipping_Method', 'Supplier', 'Customer', 'Invoice_Number', 'Payment_Terms'
# Variable Types:
#
# Text - Transaction_ID, Country, Product, Import_Export, Date, Category, Port, Shipping_Method, Supplier, Customer, Payment_Terms
# Number- Integer - Quantity, Customs_Code, Invoice_Number
# Number- Decimals - Value, Weight
# Data Variable Category:
#
# Index- Transaction_ID, Customs_Code, Invoice_Number, Product, Supplier, Customer
# Categorical- Nominal - Import_Export, Category, Shipping_Method, Payment_Terms, Country
# Categorical- Ordinal -
# Non-Categorical- Quantity, Vartl, Date, Po
# rt, Weight]orical
# is tools and frameworks..

# %% [markdown]
# # Objectives
#
# 1. **Data Loading and Inspection**: Importing the dataset and inspect its structure to understand its content.
# 2. **Data Cleaning**: Identifying and handling the  missing values or inconsistencies within the dataset.
# 3. **Data Sampling**: Creating a random sample of 2000 records from the dataset for detailed exploration.
# 4. **Exploratory Data Analysis (EDA)**: Using descriptive statistics and visualizations to analyze the key characteristics of the dataset.
# 5. **Feature Engineering**: Creating new features from existing data to improve analysis or predictions.
# 6. **Insights and Recommendations**: Summarizing findings and suggest data-driven recommendations based on the analysis.

# %% [markdown]
# # Problem Statement
#
# The dataset utilized in this analysis encompasses data on imports and exports. The objective is to explore, clean, and analyze this dataset to identify patterns and insights related to trade statistics. We will employ the Pandas and Numpy libraries for data wrangling, visualization, and analysis to extract actionable insights.

# %% [markdown]
# **ANALYSIS**
#
# **1.PIE CHART**
#    #Distribution of imports and exports
#    This pie chart displays the distribution of imports versus exports, with imports at 50.9% and exports at 49.1%. To provide an advanced statistical
#    analysis for your MBA project, we will examine the pie chart in terms of the following concepts: overall balance, trade strategies, statistical
#    significance, and recommendations.
#
#    **Proportional Analysis:**
#
# The pie chart indicates a near-balanced trade ratio, with imports slightly outweighing exports (by 1.8%).
# A ratio close to 50-50 could be seen as indicative of a balanced trade environment, but slight discrepancies can have strategic implications depending on the industry or market.
# Since imports are higher than exports, this may indicate a trade deficit for this period, although the difference is marginal. Trade deficits imply that the economy might be more reliant on foreign goods/services.
# A deeper analysis can involve using a Z-test or Chi-square test to determine if the difference between imports and exports is statistically significant, especially if this is part of a larger dataset over time.
#
# **Recommendations**
#
# **Focus on Export Promotion:**
# Given the small gap between imports and exports, it would be strategic to focus on policies that promote export growth. This could involve:
# A) Incentivizing local industries to produce more for export markets.
# B) Trade agreements that reduce tariffs and create easier market access for local products.
# C) Investment in innovation and technology that improves the competitiveness of domestic products abroad.
#
#
#
#
# **2.HEATMAP**
# **Correlation Interpretation:**
# Quantity vs. Value: The correlation coefficient is -0.0073, indicating almost no linear relationship between quantity and value. This implies that the number of units sold or moved does not significantly influence the value of the transaction.
# Quantity vs. Weight: The correlation coefficient is 0.01, which also suggests an almost negligible relationship between quantity and weight. This could be due to the fact that products with different densities or packaging might distort the relationship.
# Value vs. Weight: The correlation coefficient is 0.0041, again indicating no significant relationship between the value of the products and their weight.
#
# **Insights:**
#
# **Independence:**The lack of strong correlations between quantity, value, and weight suggests that these variables operate independently. For instance, higher value products may not necessarily weigh more or come in larger quantities, which might reflect the nature of diverse product categories (e.g., electronics vs. food products).
#
# **Data Characteristics:** The small correlation values indicate that outliers or product-specific characteristics may be influencing the dataset, making traditional linear models less applicable. More complex relationships, such as non-linear dependencies or categorical influences (e.g., product type), might need to be explored.
#
# **Clustering Analysis:**
# To better understand the relationships between these variables, you could apply a clustering technique like K-means or hierarchical clustering. This may reveal that specific product types behave differently (e.g., luxury items with low quantity and high value).
#
# **Non-linear Models:**
# Explore non-linear regression techniques or machine learning models (e.g., decision trees or random forests) to understand if there are hidden patterns in the data that cannot be captured with linear correlation alone.
#
# **Data Segmentation:**
# Segment the data by category or other relevant factors (such as seasonality) and check correlations within each segment. It's possible that different product categories behave differently.
#
# **Recommendations**
#
# **Inventory Management:** Since there is little correlation between quantity and weight, consider optimizing your inventory management based on product-specific characteristics, like perishability or seasonal demand, rather than relying on overall volume or size.
#
# **Product-Specific Marketing:** Given that there is no clear relationship between the variables, it could be beneficial to employ targeted marketing strategies for different product types. High-value, low-quantity items may require more personalized marketing approaches, while low-value, high-weight items might benefit from bulk sale strategies or promotions.
#
#
#
#
# **3.BOXPLOT**
#
# **Median** (the line in the box): This represents the middle value of the data for each category. It gives an idea of the central tendency.
# **Interquartile Range (IQR) (the box length):** This is the range between the 25th percentile (Q1) and the 75th percentile (Q3). It measures the spread of the middle 50% of the data, giving insight into variability.
# **Whiskers:** These extend to the smallest and largest values within 1.5 times the IQR. Data points outside this range are considered outliers.
# **Outliers** (data points outside whiskers): Extreme values that might be worth further investigation.
#
# **Recommendations**
#
# **Product Mix and Profit Maximization:**
#
# In categories like Toys where the transaction values are relatively low, focus on bundling products or offering value-added services to increase the perceived value. This can raise the average transaction value and increase profitability.
#
# **Category-Specific Promotions:**
#
# Since Clothing and Electronics exhibit some degree of pricing consistency, they could benefit from seasonal promotions that stimulate demand without disrupting overall pricing strategies. Consider using flash sales or limited-time offers during peak shopping seasons to boost sales.
#
#
#
# **4.BAR GRAPH**
#
# The quantity of products shipped using Air, Land, and Sea is nearly identical, as reflected by the similar heights of the bars. Each method ships approximately 5 million units, indicating that there is no significant disparity in the usage of these three shipping methods for product transport.
# **Cost vs. Speed Trade-off:**
# While this chart only shows quantity, it raises questions about the cost-effectiveness of using Air shipping at such high volumes. Since Air shipping is generally more expensive, the similar quantities might not reflect an optimal shipping strategy if there isn’t a corresponding need for speed.
#
# **Operational Constraints:**
# The balanced quantities across shipping methods might reflect logistical constraints, such as warehouse capacities, shipping routes, or infrastructure limitations. It could also point to an even distribution of products across different regions, where Air, Land, and Sea shipping are equally necessary.
#
# **Recommendations:**
#
# **Segmentation of Shipping Methods:**
# Segment shipping by product type: Not all products require the same urgency. High-value or time-sensitive goods (e.g., perishable items, luxury goods) should be prioritized for Air shipping. On the other hand, bulk and non-urgent products (e.g., machinery, furniture) can be shipped using Land or Sea to optimize costs.
# For instance, this plot could be enhanced by breaking it down further by product category (as seen in your earlier plots). This would allow for a more detailed analysis of which categories benefit from which shipping method, helping to fine-tune the logistics strategy.
#
# **Monitor Customer Satisfaction:**
# While cost is important, it’s also crucial to measure customer satisfaction based on delivery speed and shipping method. If shifting from Air to Land or Sea shipping reduces delivery times significantly, it could negatively impact customer satisfaction, especially for time-sensitive products. Consider running customer satisfaction surveys or A/B tests to assess how different shipping methods affect customer experience.
#
#
#
# **5. LINE CHART**
#
#  **Seasonal Trends**
# Exports show significant fluctuation over the months, with peaks in months like February (Month 2), May (Month 5), and September (Month 9), followed by sharp declines.
# Imports, however, remain more stable compared to exports, though they also show a decline from January to June, with minimal values for the second half of the year.
#
# A possible interpretation of this trend could indicate seasonal demand for export-related industries, possibly driven by external demand factors such as international trade agreements or global economic cycles.
#
# **Monthly Comparison**
# January and February see substantial activity in both exports and imports, indicating strong initial demand.
# April and August show convergence, where the export and import values are nearly the same, suggesting that the trade balance is more stable during these periods.
# December represents a period of low activity for both categories, with the lowest export value. This could indicate the impact of holidays or year-end effects on the trading cycle.
#
# **Trade Imbalance**
#
# For most of the months, exports exceed imports, indicating that the economy might have a trade surplus during these periods.
# The gap is largest in February and September, suggesting strong international demand or favorable trade conditions for export-oriented industries.
# The only month where imports are higher than exports is May, which could point to increased domestic demand for goods or changes in international supply chains affecting import levels.
#
#
# **Volatility in Export Values**
# The sharp rise and fall in export values suggest that this sector may be highly influenced by external factors such as international demand, currency fluctuations, or changing tariffs. This could lead to unpredictability for businesses that depend on consistent export markets.
# The unpredictability could pose risks to exporters, making it important for companies to have diversified trade agreements or to hedge against currency risks.
#
# **Recommendations:**
#
# **Risk Management for Exporters:**
# Given the volatility in export values, businesses should focus on diversifying their international markets to minimize dependency on any single country. They should also consider financial hedging tools to protect against currency fluctuations that may impact export profitability.
#
#
# **Import Stabilization Strategies:**
# The consistent decline in import values suggests a potential issue in supply chains or domestic consumption. Companies should investigate their supply chain efficiency and possibly explore alternate suppliers or renegotiate terms to stabilize the import flow.

# %% [markdown]
# **OBSERVATIONS**
#
# Dominance of Sea Shipping for Exports: Sea-based exports generate the highest trade value. Significant Imports via Land and Sea: Imports via land and sea shipping methods exhibit high trade values, with land-based imports nearly matching sea-based exports. Variation in Shipping Method Performance: Air shipping appears to have a smaller impact compared to sea and land methods, likely due to higher costs or lower capacity. Product Category Insights: Certain product categories significantly enhance profitability, indicating that focusing on these areas could improve business outcomes. Seasonal Trends in Trade Volume: Fluctuations in the data suggest seasonal trends, showing increased trade volumes at specific times.

# %% [markdown]
# **Managerial insights|RECOMMENDATION**
#
#
#
# 1.Monitoring regulatory changes.For instance, all trades seem to be conducted via air shipment. Managers could consider alternate, possibly cheaper shipping methods based on the weight and customs costs.
#
#
#
# 2.Carefully looking upon our weights according to the output.
#
#
#
# 3.We can add transaction value which is important for the analysis.
#
#
#
#
# 4. Analyzing how different shipping methods (e.g., Air) affect the trade volume and cost (Customs Code, Weight). This helps in managing logistics and optimizing shipping costs.
#
#
#
#
# 5.Identifying which customers and suppliers are generating the most business. This can help in focusing on maintaining relationships with high-value clients and suppliers.
#
#
#
#
# 6.Analyzing the payment terms being used (e.g., Prepaid, Cash on Delivery, Net 60) and their impact on cash flow. This insight helps in financial planning and risk management.
#
#
#
#
# 7.Analyzing the payment terms being used (e.g., Prepaid, Cash on Delivery, Net 60) and their impact on cash flow. This insight helps in financial planning and risk management.
#
#
#
# 8. Identifying the countries with the highest export and import quantities. This will help in understanding which countries are your biggest trading partners and where business is strongest.
#
#
#
#
# 9.The dashboard could reveal that export transactions peak during specific months (e.g., July–August) for certain products like Clothing or Machinery, allowing managers to align production or inventory planning with demand cycles.
#
#
#
#
#
# 10.Tracking the Customs Code and Weight metrics to ensure compliance with customs regulations, and assess the impact of customs-related expenses on trade profitability.

# %% [markdown]
# **CONCLUSION**
#
#
#
# These findings highlight critical insights into import and export activities, providing a foundation for strategic decision making.The patterns observed can help inform stakeholders on potential opportunities and risks in the trading landscapes.Based on the provided dataset, the import-export activities showcase diverse trade relationships across countries, with a strong reliance on air shipping. High-value products like *Machinery* and *Clothing* lead export revenues, while *Electronics* are the primary import category. Key partners include countries like *Colombia*, *Chile*, and *Turkey*, with top-performing suppliers such as *Mendez, Jones, and Johnson* and customers like *Seth Hall*. Payment terms favor *Prepaid*, providing good cash flow management, although *Net 60* terms require close monitoring. This data emphasizes the importance of optimizing logistics, diversifying shipping methods, and managing financial risk effectively.

# %%
# Import Relevant Python Libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import norm
from mpl_toolkits.mplot3d import Axes3D

# %%
#Import dataset
df= pd.read_csv(r"C:\Users\hp\Downloads\Imports_Exports_Dataset (1).csv")

# %%
#Random Sample from the dataset
df_sample = df.sample(n=3001, random_state = 55006)

# %%
# Dimensions of the data 
dimensions = df_sample.shape
print('No. of rows in the data are:',dimensions[0])
print('No. of columns in the data are:',dimensions[1])
# Out:
# No. of rows in the data are: 3001
# No. of columns in the data are: 16

# %% [markdown]
# # Analysis of Data

# %% [markdown]
# Most preferred shipping method by value is sea
# least preferred shipping method by value is Air

# %% [markdown]
#  **BAR PLOT TOTAL VALUE BY COUNTRY**

# %% [markdown]
#  **PIE CHART IMPORT V/S EXPORT**

# %%
# Group by Import_Export and count the occurrences
import_export_count = df_sample['Import_Export'].value_counts()

# Create the pie chart
import_export_count.plot(kind='pie', autopct='%1.1f%%', figsize=(7, 7), startangle=90)
plt.title('Distribution of Import vs Export')
plt.ylabel('')  # Removes the default y-label
plt.show()

# %%
# SCATTER PLOT QUANTITY V/S VALUE

# %% [markdown]
# **Observation/Finding **

# %% [markdown]
# # Trade volume trends
# The total volume of import and export is not stable as we can see that from 2019-20 the value of export has decreased.
# # Top trading partners
# The analysis identified greenland and Norfolk island are top trading partners.
# # seasonal patterns
# There are noticeable seasonal fluctuations in trade activities.

# %%
corr = df_sample[['Quantity', 'Value', 'Weight']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Between Quantity, Value, and Weight')
plt.show()

# %%
sns.boxplot(x='Category', y='Value', data=df_sample)
plt.title('Distribution of Transaction Value by Category')
plt.xticks(rotation=45)
plt.show()

# %%
# Corrected Bar Plot for Quantity by Shipping Method
plt.figure(figsize=(10, 6))


shipping_quantity = df_sample.groupby("Shipping_Method")["Quantity"].sum()

plt.bar(x = shipping_quantity.index, height = shipping_quantity.values, color='skyblue')


plt.xlabel('Shipping Method')
plt.ylabel('Quantity')
plt.title('Quantity of Products by Shipping Method')
plt.xticks(rotation=45)


plt.show()

# %%
df_sample['Date'] = pd.to_datetime(df_sample['Date'], format='%d-%m-%Y')

# Extract month from the date
df_sample['Month'] = df_sample['Date'].dt.month

# Group by month and Import_Export, then calculate the average transaction value
monthly_avg_value = df_sample.groupby(['Month', 'Import_Export'])['Value'].mean().unstack()

# Plot the line graph
plt.figure(figsize=(8, 6))

# Plot each import and export line
for column in monthly_avg_value.columns:
    plt.plot(monthly_avg_value.index, monthly_avg_value[column], marker='o', label=column)

# Add labels and title
plt.title('Average Value of Transactions by Month')
plt.xlabel('Month')
plt.ylabel('Average Transaction Value')
plt.grid(True)
plt.legend(title='Transaction Type')  # Add legend to distinguish between imports and exports

# Show the plot
plt.tight_layout()
plt.show()
